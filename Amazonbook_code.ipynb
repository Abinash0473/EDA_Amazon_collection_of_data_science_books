# %%
#importing required applocations such as numpy,pandas,matplotlib,seaborn for data analysis

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# loading the data set

# %%
df = pd.read_csv(r'C:\Users\KIIT\Documents\temp data\final_book_dataset_kaggle.csv', encoding= 'unicode_escape')

# %%
# BASIC INFORMATION OF THE DATA

# %%
df.shape
# Out:
# (946, 18)

# %%
df.head()
# Out:
#                                                title  \
# 0  Becoming a Data Head: How to Think Speak and U...
# 1  Ace the Data Science Interview: 201 Real Inter...
# 2  Fundamentals of Data Engineering: Plan and Bui...
# 3  Essential Math for Data Science: Take Control ...
# 4  Data Science for Business: What You Need to Kn...
#
#                               author  price  pages  avg_reviews  n_reviews  \
# 0  [Alex J. Gutman,Jordan Goldmeier]  24.49  272.0          4.6        184
# 1             [Nick Singh,Kevin Huo]  26.00  301.0          4.5        599
# 2            [Joe Reis,Matt Housley]  50.76  446.0          5.0         33
# 3                     [Thomas Nield]  44.80  347.0          4.5         27
# 4       [Foster Provost,Tom Fawcett]  36.99  413.0          4.5        970
#
#    star5  star4  star3  star2  star1             dimensions       weight  \
# 0   0.74   0.18   0.05   0.02   0.01    6 x 0.62 x 9 inches  12.5 ounces
# ...

# %%
df.head(70)
# Out:
#                                                 title  \
# 0   Becoming a Data Head: How to Think Speak and U...
# 1   Ace the Data Science Interview: 201 Real Inter...
# 2   Fundamentals of Data Engineering: Plan and Bui...
# 3   Essential Math for Data Science: Take Control ...
# 4   Data Science for Business: What You Need to Kn...
# ..                                                ...
# 65  PYTHON FOR DATA SCIENCE: The Ultimate Beginner...
# 66  97 Things About Ethics Everyone in Data Scienc...
# 67  Data Science for Marketing Analytics: A practi...
# 68  Video Data Analysis: How to Use 21st Century V...
# 69                The Beginners Guide to Data Science
#
#                                           author  price  pages  avg_reviews  \
# 0              [Alex J. Gutman,Jordan Goldmeier]  24.49  272.0          4.6
# 1                         [Nick Singh,Kevin Huo]  26.00  301.0          4.5
# 2                        [Joe Reis,Matt Housley]  50.76  446.0          5.0
# ...

# %%
df.nunique()
# Out:
# title            946
# author           765
# price            542
# pages            392
# avg_reviews       22
# n_reviews        260
# star5             68
# star4             51
# star3             32
# star2             22
# star1             19
# dimensions       699
# weight           303
# language           2
# publisher        880
# ISBN_13          945
# link             946
# complete_link    946
# dtype: int64

# %%
# CHECKING FOR UNIQUE VALUES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          946 non-null    object
#  1   author         824 non-null    object
#  2   price          944 non-null    float64
#  3   pages          934 non-null    float64
#  4   avg_reviews    823 non-null    float64
#  5   n_reviews      946 non-null    int64
#  6   star5          946 non-null    float64
#  7   star4          946 non-null    float64
#  8   star3          946 non-null    float64
#  9   star2          946 non-null    float64
#  10  star1          946 non-null    float64
#  11  dimensions     914 non-null    object
#  12  weight         943 non-null    object
#  13  language       943 non-null    object
#  14  publisher      942 non-null    object
#  15  ISBN_13        945 non-null    object
#  16  link           946 non-null    object
# ...

# %%
#CKECKING FOR NULL VALUES

# %%
pd.isnull(df)
# Out:
#      title  author  price  pages  avg_reviews  n_reviews  star5  star4  star3  \
# 0    False   False  False  False        False      False  False  False  False
# 1    False   False  False  False        False      False  False  False  False
# 2    False   False  False  False        False      False  False  False  False
# 3    False   False  False  False        False      False  False  False  False
# 4    False   False  False  False        False      False  False  False  False
# ..     ...     ...    ...    ...          ...        ...    ...    ...    ...
# 941  False   False  False  False        False      False  False  False  False
# 942  False   False  False  False        False      False  False  False  False
# 943  False   False  False  False        False      False  False  False  False
# 944  False   False  False  False        False      False  False  False  False
# 945  False   False  False  False        False      False  False  False  False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# title              0
# author           122
# price              2
# pages             12
# avg_reviews      123
# n_reviews          0
# star5              0
# star4              0
# star3              0
# star2              0
# star1              0
# dimensions        32
# weight             3
# language           3
# publisher          4
# ISBN_13            1
# link               0
# complete_link      0
# dtype: int64

# %%
df.shape
# Out:
# (946, 18)

# %%
# DELEATING OF NULL VALUES FROM THE DATASET

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (698, 18)

# %%
pd.isnull(df).sum()
# Out:
# title            0
# author           0
# price            0
# pages            0
# avg_reviews      0
# n_reviews        0
# star5            0
# star4            0
# star3            0
# star2            0
# star1            0
# dimensions       0
# weight           0
# language         0
# publisher        0
# ISBN_13          0
# link             0
# complete_link    0
# dtype: int64

# %%
#No more Null values of data present

# %%
df.columns
# Out:
# Index(['title', 'author', 'price', 'pages', 'avg_reviews', 'n_reviews',
#        'star5', 'star4', 'star3', 'star2', 'star1', 'dimensions', 'weight',
#        'language', 'publisher', 'ISBN_13', 'link', 'complete_link'],
#       dtype='object')

# %%
# CHECKING AND ANALYSIS OF DATA TYPES OF EACH COLUMN ELEMENTS

# %%
df['title'].dtypes
# Out:
# dtype('O')

# %%
df['author'].dtypes
# Out:
# dtype('O')

# %%
df['price'].dtypes
# Out:
# dtype('float64')

# %%
df['pages'].dtypes
# Out:
# dtype('float64')

# %%
df['avg_reviews'].dtypes
# Out:
# dtype('float64')

# %%
df['n_reviews'].dtypes
# Out:
# dtype('int64')

# %%
df['star5'].dtypes
# Out:
# dtype('float64')

# %%
df['star4'].dtypes
# Out:
# dtype('float64')

# %%
df['star3'].dtypes
# Out:
# dtype('float64')

# %%
df['star2'].dtypes
# Out:
# dtype('float64')

# %%
df['star1'].dtypes
# Out:
# dtype('float64')

# %%
df['dimensions'].dtypes
# Out:
# dtype('O')

# %%
df['weight'].dtypes
# Out:
# dtype('O')

# %%
df['language'].dtypes
# Out:
# dtype('O')

# %%
df['publisher'].dtypes
# Out:
# dtype('O')

# %%
df['ISBN_13'].dtypes
# Out:
# dtype('O')

# %%
df['link'].dtypes
# Out:
# dtype('O')

# %%
df['complete_link'].dtypes
# Out:
# dtype('O')

# %%
# ANALYSIS OF THE DATA

# %%
df.describe()
# Out:
#             price        pages  avg_reviews    n_reviews       star5  \
# count  698.000000   698.000000   698.000000   698.000000  698.000000
# mean    50.454513   430.237822     4.444556   150.881089    0.719140
# std     36.399546   204.349437     0.401976   535.166053    0.150545
# min      8.990000    48.000000     1.000000     1.000000    0.110000
# 25%     31.967500   286.250000     4.300000    10.000000    0.620000
# 50%     41.990000   392.000000     4.500000    33.000000    0.720000
# 75%     51.840000   543.500000     4.700000   101.750000    0.800000
# max    279.950000  1728.000000     5.000000  7563.000000    1.000000
#
#             star4       star3       star2       star1
# count  698.000000  698.000000  698.000000  698.000000
# mean     0.162020    0.067049    0.030444    0.021261
# std      0.105296    0.063199    0.040292    0.033373
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.110000    0.000000    0.000000    0.000000
# ...

# %%
df.columns
# Out:
# Index(['title', 'author', 'price', 'pages', 'avg_reviews', 'n_reviews',
#        'star5', 'star4', 'star3', 'star2', 'star1', 'dimensions', 'weight',
#        'language', 'publisher', 'ISBN_13', 'link', 'complete_link'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'price',data = df)

# %%
ax = sns.countplot(x = 'pages',data = df)

# %%
ax = sns.countplot(x = 'avg_reviews',data = df)

# %%
ax = sns.countplot(x = 'weight',data = df)

# %%
ax = sns.countplot(x = 'avg_reviews',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(x = 'language',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
from matplotlib import colors

# %%
sns.pairplot(df)
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['price'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='price',y='pages',hue='avg_reviews',data=df)
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['avg_reviews'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['weight'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['star5'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['language'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='avg_reviews',kind='box',data=df)
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='pages',kind='box',data=df)
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
myf=df['avg_reviews'].value_counts()
myf
# Out:
# avg_reviews
# 4.6    106
# 4.5    100
# 4.4     86
# 5.0     70
# 4.7     68
# 4.3     57
# 4.2     44
# 4.8     36
# 4.1     31
# 4.0     20
# 4.9     17
# 3.9     15
# 3.8     10
# 3.5     10
# 3.7      9
# 3.3      5
# 3.2      4
# 3.6      4
# 3.0      3
# 1.0      1
# 2.0      1
# 3.1      1
# Name: count, dtype: int64

# %%
myf=df['weight'].value_counts()
myf
# Out:
# weight
# 1.6 pounds     10
# 1.5 pounds      9
# 1.1 pounds      9
# 2.15 pounds     9
# 14.4 ounces     8
#                ..
# 2.11 pounds     1
# 3.12 pounds     1
# 3.06 pounds     1
# 3.7 pounds      1
# 9.1 ounces      1
# Name: count, Length: 269, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
myf.plot(kind='pie')
plt.show()

# %%
myf.plot(kind='bar')
plt.show()

# %% [markdown]
# AFTER ANALYSIS OF THE DATA THE FOLLOWING CONCLUSION CAN BE MADE:-
# 1.PRICE:-
#   -The mean value of Price from all the books in amazon is 50.456513.
#   -DATA STRUCTURE AND ALGORITHMS: BUILD IN PYTHON
